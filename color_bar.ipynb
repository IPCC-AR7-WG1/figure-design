# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LinearSegmentedColormap

# %%
def plot_colorbar(cmap, title):
    fig, ax = plt.subplots(figsize=(8, 1.2))
    fig.subplots_adjust(bottom=0.5)

    norm = mpl.colors.Normalize(vmin=0, vmax=100)
    cb = mpl.colorbar.ColorbarBase(
        ax,
        cmap=cmap,
        norm=norm,
        orientation='horizontal'
    )

    ax.set_title(title, fontsize=12)
    plt.show()

# %%
# --- Temperature (Divergent: blue → white → red) --- Ref: colorbrewer 
temp_div = LinearSegmentedColormap.from_list(
    "temp_div",
    ["#053061",'#2166ac', "#4393c3",'#92c5de', "#d1e5f0",'#f7f7f7', '#fddbc7', "#f4a582", "#d6604d", "#b2182b", '#67001f']
)

# --- Temperature (Sequential: yellow → orange → dark brown) ---
temp_seq = 'afmhot_r' # reverse of 'afmhot'

plot_colorbar(temp_div, "Temperature (Divergent)")
plot_colorbar(temp_seq, "Temperature (Sequential)")

# %%
# --- Precipitation (Divergent: brown → white → teal) ---
prec_div = 'BrBG'

# --- Precipitation (Sequential: light green → dark teal) ---
brbg = plt.get_cmap('BrBG')
green_1 = brbg(0.75)
green_2 = brbg(0.95) 
green_3 = brbg(1.0)

prec_seq = LinearSegmentedColormap.from_list(
    "prec_seq",
    ["#e5f5e0", "#99d8c9", green_1, green_2, green_3]
)

plot_colorbar(prec_div, "Precipitation (Divergent)")
plot_colorbar(prec_seq, "Precipitation (Sequential)")

# %%
# --- Wind (Divergent: purple/blue → white → green) ---
wind_div = LinearSegmentedColormap.from_list(
    "wind_div",
    ["#3b0f70", "#2c7fb8", "#f7f7f7", "#41ab5d", "#006400"]
)

# --- Wind (Sequential: yellow → green → dark green) ---
wind_seq = 'YlGn'

plot_colorbar(wind_div, "Wind (Divergent)")
plot_colorbar(wind_seq, "Wind (Sequential)")

# %%
# --- Cryosphere (Divergent: dark purple → light blue → white → light yellow → dark yellow) ---
cryo_div = LinearSegmentedColormap.from_list(
    "cryo_div",
    ["#2b2c7c", "#1f78b4", "#f7f7f7", "#bdb76b", "#4d4d00"]
)

# --- Cryosphere (Sequential: dark blue → light blue → white) ---
cryo_seq = 'Blues_r'

plot_colorbar(cryo_div, "Cryosphere (Divergent)")
plot_colorbar(cryo_seq, "Cryosphere (Sequential)")

# %%
# --- Chemistry (Divergent: dark green → light green → white → light purple → dark purple) ---
chem_div = 'PRGn_r'

# --- Chemistry (Sequential: light green → medium green → dark purple) ---
prgnr = plt.get_cmap('PRGn_r')
purple_1 = prgnr(0.9)
purple_2 = prgnr(1.0)

chem_seq = LinearSegmentedColormap.from_list(
    "chem_seq",
    ["#e5f5e0", "#a1d99b","#8a848b", purple_1, purple_2]
)

plot_colorbar(chem_div, "CO2/CH4/Aerosols (Divergent)")
plot_colorbar(chem_seq, "CO2/CH4/Aerosols (Sequential)")

# %%
# --- Sea Level (Divergent: dark blue → light blue → white → light orange → dark orange) ---
slev_div = LinearSegmentedColormap.from_list(
    "slev_div",
    ["#045a8d", "#2b8cbe", "#f7f7f7", "#fdb863", "#8c510a"]
)

# --- Sea Level (Sequential: pale green → blue → dark navy) ---
slev_seq = LinearSegmentedColormap.from_list(
    "slev_seq",
    ["#f4f6f0", "#e8f1bf", "#014780F6", "#08306b"]
)

plot_colorbar(slev_div, "Sea Level (Divergent)")
plot_colorbar(slev_seq, "Sea Level (Sequential)")

# %%
# # --- Other Variables (Divergent)---
# other_div = LinearSegmentedColormap.from_list(
#     "other_div",
#     ["#313695", "#4575b4", "#74add1", "#abd9e9", "#e0f3f8", "#ffffbf", 
#      "#fee090", "#fdae61", "#f46d43", "#d73027", "#a50026"]
# )

# # --- Other Variables (Sequential)---
# other_seq_1 = LinearSegmentedColormap.from_list(
#     "other_seq_1",
#     ["#253494", "#2c7fb8", "#479878", "#9de84c", "#ffff33"]
# )

# other_seq_2 = LinearSegmentedColormap.from_list(
#     "other_seq_2",
#     ["#e0f3f8", "#74add1", "#8073ac", "#7a0177", "#3f007d"]
# )

# other_seq_3 = LinearSegmentedColormap.from_list(
#     "other_seq_3",
#     ["#08306b", "#1b9e77", "#d9ef8b", "#fdae61", "#f1b6da"]
# )


# plot_colorbar(other_div, "Other Variables (Divergent)")
# plot_colorbar(other_seq_1, "Other Variables (Sequential 1)")
# plot_colorbar(other_seq_2, "Other Variables (Sequential 2)")
# plot_colorbar(other_seq_3, "Other Variables (Sequential 3)")
